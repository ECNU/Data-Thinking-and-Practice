# %%
from github import Github

# 你的GitHub个人访问令牌
token = 'token'

# 创建Github对象
g = Github(token)

user = g.get_user()

following = user.get_following()

for follower in following:
    print(f"Follower: {follower.login}")

    repos = follower.get_repos()

    for repo in repos:
        print(f"  Repo: {repo.name}")

        with open('follower_repos.txt', 'a') as file:
            file.write(f"{follower.login}/{repo}\n")
# Out:
# Follower: tsq
#   Repo: algo
#   Repo: ali-sms
#   Repo: cmon
#   Repo: HumanizeDateTime
#   Repo: webhooksha256
#   Repo: youdao-cli-translator
# Follower: frank-zsy
#   Repo: Alarm
#   Repo: alibaba-infra-website
#   Repo: apachecon-acasia
#   Repo: azure-guidance
#   Repo: BasicCodes
#   Repo: blog
#   Repo: bot-test
#   Repo: Cerberus
#   Repo: ClickHouse
#   Repo: clickhouse-github-log-importer
#   Repo: collabobot
#   Repo: CollabobotTester
#   Repo: community
#   Repo: core
#   Repo: CSharpLearning
#   Repo: data-sync
#   Repo: datav-backend
#   Repo: edu-bot-test
#   Repo: fluid
#   Repo: frank-zsy
#   Repo: gar
#   Repo: Git-Github-notes-for-study
#   Repo: gitbook
#   Repo: gitcourse
#   Repo: github-graphql-client
#   Repo: github-graphql-fetcher
#   Repo: git_faq
#   Repo: graph-data-science
#   Repo: Hackathon
#   Repo: hacking-force
#   Repo: hypertrons
#   Repo: hypertrons-crx
#   Repo: ICA_Demo
#   Repo: iterated-prisoners-dilemma
#   Repo: kubevela
#   Repo: livecode-crx
#   Repo: MicrosoftAzureDoc
#   Repo: Monitor
#   Repo: ncov-report-mini-program
#   Repo: ncov-report-mini-program-server
#   Repo: nebula-community
#   Repo: neo4j-procedure-template
#   Repo: node
#   Repo: noslate
#   Repo: open-crawler
#   Repo: open-digger
#   Repo: open-galaxy
#   Repo: open-research
#   Repo: Open-source-training-camp
#   Repo: OpenClubhouse
#   Repo: openrank-neo4j-gds
#   Repo: OSSDevGov2021
#   Repo: oxford
#   Repo: PCA_ICA_DEMO
#   Repo: PHPCoreTechnologyAndBestPractise
#   Repo: pouch
#   Repo: pouchrobot
#   Repo: prisoner-dilemma-game-theory
#   Repo: probot
#   Repo: ReadingNotes
#   Repo: rest.js
#   Repo: slides
#   Repo: svgwg
#   Repo: TechBlog
#   Repo: tengine-ingress
#   Repo: Test
#   Repo: test-gitcourse
#   Repo: ttoos
#   Repo: vue-minesweeper
#   Repo: vue-shop
#   Repo: wuhan2020
# Follower: Brucezhou1979
#   Repo: BDVisual
#   Repo: DataStructureCourse
#   Repo: KDDDataIO
#   Repo: KM
#   Repo: MapMeasure
#   Repo: osgearth
# Follower: will-ww
#   Repo: .github
#   Repo: AccelerateDevOps
#   Repo: blockpy
#   Repo: hello-world
#   Repo: IntroDaSE
#   Repo: mermaid
#   Repo: metro
#   Repo: OpenEdu
#   Repo: OpenSourceLicense-FQA
#   Repo: ospo101
#   Repo: ppcloudcomputing
#   Repo: PythonFromDAToDS
#   Repo: README
#   Repo: will-ww
#   Repo: wuhan2020
#   Repo: x-lab
# Follower: bifenglin
#   Repo: 2022-SocialComputing
#   Repo: ant-design
#   Repo: AutoGPT
#   Repo: benchmarking-gnns
#   Repo: BotHawk
#   Repo: build-web-application-with-golang
#   Repo: cli
#   Repo: cobra
#   Repo: Complex-Network
#   Repo: CS-Notes
#   Repo: DaSE101
#   Repo: DaSE_lab
#   Repo: DataMiningAlgorithm
#   Repo: dataStructure
#   Repo: ddc
#   Repo: designpattern
#   Repo: docerKfcoding
#   Repo: DTEM
#   Repo: dva
#   Repo: EduPerf
#   Repo: EduTechResearch
#   Repo: engine-api
#   Repo: entry
#   Repo: eureka
#   Repo: fission
#   Repo: free-programming-books-zh_CN
#   Repo: gcgl
#   Repo: GCN_study
#   Repo: gitcourse-example-course
#   Repo: go-build-template
#   Repo: golang-docker-client
#   Repo: GraphScope
#   Repo: homework
#   Repo: javaUI
#   Repo: katacoda-scenarios
#   Repo: LearningNotes
#   Repo: LeetCode
#   Repo: LeetCodeAnimation
#   Repo: llama
#   Repo: meli
#   Repo: moby
#   Repo: open-digger
#   Repo: open-leaderboard
#   Repo: open-perf
#   Repo: open-research
#   Repo: open-wonderland
#   Repo: OpenSODA
#   Repo: OpenTEA101
#   Repo: oss101-awesome-list
#   Repo: OSSDevGov2022
#   Repo: OSS_Chat
#   Repo: outdated_component_analysis
#   Repo: papers-notebook
#   Repo: qac
#   Repo: react-contextmenu
#   Repo: react-lz-editor
#   Repo: react-sortable-tree
#   Repo: ssgl
#   Repo: superset
#   Repo: system-design-101
#   Repo: TongjiThesis
#   Repo: VP_Graph
#   Repo: vue-element-admin
#   Repo: WebApp
#   Repo: wuhan2020
# Follower: yoyo-wu98
#   Repo: AppearanceEraser
#   Repo: arcgis-appstudio-samples
#   Repo: ArcGIS-DotNet-Routing-Sample
#   Repo: awesome-computer-vision
#   Repo: awesome-stock-resources
#   Repo: binance-trade-bot
#   Repo: bookstore
#   Repo: building-mobile-apps-flex
#   Repo: CalliGAN
#   Repo: cloudcomputing_DaSE_2019Fall
#   Repo: clrs-solution
#   Repo: computer-system-3th-edition-
#   Repo: cord-19-emotion-analysis---visualization
#   Repo: core-js
#   Repo: cs-video-courses
#   Repo: deepdream
#   Repo: discrete-mathematics-and-its-applications-7th-edition-
#   Repo: dl_DaSE2019Fall_assignments
#   Repo: document
#   Repo: dos
#   Repo: draw-server
#   Repo: DS2014-BuildingDesktopApps
#   Repo: final
#   Repo: flowy
#   Repo: front-end-collect
#   Repo: Generative-Painting
#   Repo: gpt-neo
#   Repo: gpt-neox
#   Repo: How-to-Make-a-Computer-Operating-System
#   Repo: html5-geolocation-tool-js
#   Repo: HuobiRobot
#   Repo: impress.js
#   Repo: indoor-routing-xamarin
#   Repo: isystem
#   Repo: js-must-watch
#   Repo: language-change-tutorial
#   Repo: machine-learning-notes
#   Repo: mapbox-gl-native
#   Repo: mapbox.js
#   Repo: maps-app-javascript
#   Repo: maptalks.js
#   Repo: minix
#   Repo: Moon
#   Repo: neofetch
#   Repo: nonEuclidGraphics
#   Repo: notes_2018_fall
#   Repo: open-digger
#   Repo: open-research
#   Repo: opensea-erc1155
#   Repo: operating-system-
#   Repo: osquery
#   Repo: osx-status-bar-todo
#   Repo: PaintingLight
#   Repo: paintnet-server
#   Repo: pandas-cookbook
#   Repo: peatio
#   Repo: Processing
#   Repo: procps
#   Repo: pydata-book
#   Repo: react-map-gl
#   Repo: react-native-full-example
#   Repo: SalsaNext
#   Repo: STATS
#   Repo: study-note
#   Repo: sudoku
#   Repo: UltraTabSaver
#   Repo: vuejs-freehand-svg-draw
#   Repo: windows-build-tools
#   Repo: workflowy-clone
#   Repo: xigua
#   Repo: Yomu
# Follower: AliceCodeZhang
#   Repo: .github
#   Repo: allure-testng-example
#   Repo: android-junit5
#   Repo: androidSample
#   Repo: CIexample
#   Repo: clash-win-docs-new
#   Repo: example-shared-library
#   Repo: github-analysis-report
#   Repo: github-pages-with-jekyll
#   Repo: grafana-operator
#   Repo: iOSSampleCode
#   Repo: java-hello-world-with-gradle
#   Repo: Java-TestNG-Selenium
#   Repo: java8-tutorial
#   Repo: junit5-samples
#   Repo: methods2test
#   Repo: n8n
#   Repo: node_js-example
#   Repo: owt-client-javascript
#   Repo: owt-server
#   Repo: python-example
#   Repo: QoSTestFramework
#   Repo: sampleCode
#   Repo: SeleniumTestNGMavenExample
#   Repo: testng-junit5
#   Repo: UnitTestingPPP
#   Repo: VQA-Deep-Learning
# Follower: tyn1998
#   Repo: bilibili_flask
#   Repo: chrome-extension-boilerplate-react
#   Repo: devops_demo
#   Repo: devtron
#   Repo: dotfiles
#   Repo: dummy-charts
#   Repo: echarts
#   Repo: echarts-doc
#   Repo: echarts-examples
#   Repo: G6VP
#   Repo: gi-assets-xlab
#   Repo: hypertrons
#   Repo: hypertrons-crx
#   Repo: i3
#   Repo: learn-github-actions
#   Repo: life_tree
#   Repo: lilypond
#   Repo: mpi-demo
#   Repo: my-graduation-project
#   Repo: ngraph.native
#   Repo: open-digger
#   Repo: open-galaxy
#   Repo: open-galaxy-backup
#   Repo: open-leaderboard
#   Repo: open-research
#   Repo: open-widgets
#   Repo: open-wonderland
#   Repo: OpenSODA
#   Repo: opensumi-core
#   Repo: opensumi-devtools
#   Repo: opensumi-docs
#   Repo: opensumi-gatsby-theme
#   Repo: opensumi-hello-module
#   Repo: opensumi-ide-electron
#   Repo: orillusion-web
#   Repo: oss101-awesome-list
#   Repo: OSSDevGov2022
#   Repo: plasmo
#   Repo: plasmo-examples
#   Repo: ppi-data-provider
#   Repo: ppi-frontend
#   Repo: ppi-galaxy
#   Repo: ppi_resilience
#   Repo: react-chat-widget
#   Repo: refined-github
#   Repo: signature
#   Repo: Snap-4.0
#   Repo: sumi-devtools
#   Repo: tale
#   Repo: test-opensumi-devtools-ci
#   Repo: try-github-features
#   Repo: try-github-repo-pages
#   Repo: tyn1998
#   Repo: tyn1998.github.io
#   Repo: vim-lilypond
#   Repo: workflows-for-hypercrx
#   Repo: X-lab-website
#   Repo: zhongwenxi
# Follower: xgdyp
#   Repo: 100LinesOfCode
#   Repo: 30-Days-Of-JavaScript
#   Repo: apiflask
#   Repo: auto-editor
#   Repo: awesome-python
#   Repo: chatgpt_academic
#   Repo: ClickHouse
#   Repo: code-space
#   Repo: commentbox
#   Repo: communities
#   Repo: credtest
#   Repo: DaSE101
#   Repo: DesignThinking-LeanStartup
#   Repo: DocsGPT
#   Repo: DS-A
#   Repo: ecnu-lib-seat-reservation
#   Repo: explore
#   Repo: faster-git
#   Repo: GeneralNewsExtractor
#   Repo: git
#   Repo: git-0.01
#   Repo: git2go-example
#   Repo: gitea
#   Repo: github-explorer
#   Repo: github-trending-history
#   Repo: github_test
#   Repo: githug
#   Repo: hercules
#   Repo: hypertrons-crx
#   Repo: Interview
#   Repo: lake
#   Repo: learngo
#   Repo: mianshiya-public
#   Repo: mirai
#   Repo: moer
#   Repo: notes
#   Repo: OnlineJudgeDeploy
#   Repo: open-digger
#   Repo: open-research
#   Repo: open-wonderland
#   Repo: OSSDevGov2022
#   Repo: ossinsight
#   Repo: PaddleGAN
#   Repo: prettytable
#   Repo: probot
#   Repo: PSpider
#   Repo: puppet-padlocal
#   Repo: pygit
#   Repo: Python
#   Repo: QQZoneMood
#   Repo: qqzoneSpider
#   Repo: reaction_collector
#   Repo: sayhello
#   Repo: show-me-the-code
#   Repo: spider
#   Repo: Spoon-Knife
#   Repo: steampipe-plugin-github
#   Repo: SysMocap
#   Repo: testaction
#   Repo: tiktok
#   Repo: Typora_Free_Download
#   Repo: use-of-graph
#   Repo: vscode
#   Repo: WangDao-DataStructure
#   Repo: whale-anno
#   Repo: wonderful-sql
#   Repo: xgdyp
#   Repo: xgdyp.github.io
# Follower: 19883235
#   Repo: 19883235.github.io
#   Repo: AccelerateDevOps
#   Repo: core
#   Repo: CSAPP-Labs
#   Repo: DataScience-CS-courseware
#   Repo: designthinking2021.github.io
#   Repo: FastSpeech2
#   Repo: hexo-matery-modified
#   Repo: minix
#   Repo: MINIX3
#   Repo: ncmdump
#   Repo: OnlineJudge
#   Repo: openBilibili-1
#   Repo: python-data-visualiztion-cookbook
#   Repo: xlab-website
# Follower: zhicheng-ning
#   Repo: .github
#   Repo: android-vpn
#   Repo: AndroidLearning
#   Repo: Android_NetworkTest
#   Repo: BilibiliPlayer
#   Repo: bootstrap
#   Repo: ByteLegend
#   Repo: C-sharp-WinForm-TTMusicPlayer
#   Repo: cayman
#   Repo: chromium
#   Repo: clickhub
#   Repo: community
#   Repo: corejava
#   Repo: CS-Notes
#   Repo: DataAnalysis
#   Repo: dataease
#   Repo: DeepLearning-500-questions
#   Repo: demo-for-wechat-miniprogram-use-font-awesome
#   Repo: DeveloperCrawler
#   Repo: devops-sprinboot
#   Repo: devops_demo
#   Repo: devtools
#   Repo: docs
#   Repo: docs-1
#   Repo: DocsGPT
#   Repo: dogTorch
#   Repo: easymock
#   Repo: eBook-wareHouse
#   Repo: Face-Detection
#   Repo: fastjson
#   Repo: FigureBed
#   Repo: Financial-Knowledge-Graphs
#   Repo: FindGitHubDeveloper
#   Repo: firstWeb
#   Repo: free-api
#   Repo: fucking-algorithm
#   Repo: git-demo
#   Repo: github-action-demo
#   Repo: gitHub-Pages-Demo
#   Repo: github-slideshow
#   Repo: GraphicalDesignPatterns
#   Repo: H5Project
#   Repo: huJiangOnlineSchool
#   Repo: hypertrons-crx
#   Repo: Improved-dbscan-algorithm
#   Repo: Java
#   Repo: java-create-package-private-class
#   Repo: JavaDesignPattern
#   Repo: JavaScript-MD5
#   Repo: jedis_redisdemo
#   Repo: json-server-api
#   Repo: JustAuth
#   Repo: JustAuth-demo
#   Repo: learnGitBranching
#   Repo: learngo
#   Repo: learning-react
#   Repo: LeetCode-Practice
#   Repo: matplotlib
#   Repo: maven-webapp-Demo
#   Repo: mundana-theme-jekyll
#   Repo: MyBlog
#   Repo: nacos
#   Repo: Ncu_Community
#   Repo: od-api
#   Repo: onlineBookStore
#   Repo: open-digger
#   Repo: open-leaderboard
#   Repo: open-research
#   Repo: open-stulife-sdk
#   Repo: open-stulife-sdk-backend
#   Repo: open-wonderland
#   Repo: opencv_contrib
#   Repo: ospp-cr-bot
#   Repo: oss101
#   Repo: oss101-awesome-list
#   Repo: OSSDevGov2022
#   Repo: Pic-Go
#   Repo: Plugins
#   Repo: python-spider
#   Repo: PythonPlantsVsZombies
#   Repo: rabbitmq-website
#   Repo: signature
#   Repo: SparkMLlib
#   Repo: spring-boot-demo
#   Repo: spring-in-action-5-samples
#   Repo: spring-in-action-6-samples
#   Repo: SpringBootIntegrateRedis
#   Repo: SpringBootSourceStudy
#   Repo: sql-that-must-know
#   Repo: Test-Hypercrx-CI
#   Repo: tiktok
#   Repo: tmall
#   Repo: Waking-Up
#   Repo: weather_forecast
#   Repo: Web-Study
#   Repo: wechat-bot
#   Repo: wow-plotly
#   Repo: x-interview
#   Repo: x-java-high-concurrency-core
#   Repo: x-java-high-netty-redis-zookeeper-core
#   Repo: X-lab-website
#   Repo: x-rpc
#   Repo: x-tiktok
#   Repo: zhicheng-ning
#   Repo: zhicheng-ning.github.io
# Follower: wxharry
#   Repo: ADB-Fall2022
#   Repo: AI-Fall2022
#   Repo: anaconda3
#   Repo: AQuery2
#   Repo: Artificial-Intelligence-Autumn2019
#   Repo: asrs-front
#   Repo: autoSelfreport
#   Repo: chatapi
#   Repo: chatgpt-api
#   Repo: Cloud-and-ML-spring2023
#   Repo: cml_proj2
#   Repo: CompilerConstruction-Spring2022
#   Repo: Computer-vision
#   Repo: devops-java-sample
#   Repo: dotfiles
#   Repo: Fundamental-Algorithms-Implementation
#   Repo: gdrive-upload-action
#   Repo: github-actions-lab
#   Repo: github-repo-comparer
#   Repo: heart
#   Repo: helloJenkins
#   Repo: hexo-theme-Chic
#   Repo: hypertrons-crx
#   Repo: jenkins-cli
#   Repo: jenkins-client
#   Repo: ks-devops
#   Repo: kubesphere
#   Repo: latex
#   Repo: lazygit
#   Repo: majorHelper
#   Repo: memo
#   Repo: minesweeper
#   Repo: myLaTex
#   Repo: MyLeetCode
#   Repo: myPicoCTF
#   Repo: New-Restaurant-Rating-System-in-Yelp
#   Repo: nfs
#   Repo: NLP-fall2022
#   Repo: nlp-final-project
#   Repo: number-guessing
#   Repo: open-idea
#   Repo: OperatingSystem-Fall2021
#   Repo: prettier
#   Repo: ProgrammingLanguages-Fall2021
#   Repo: RBDA-final-report
#   Repo: RealtimeBigDataAnalysis-Spring2022
#   Repo: RepCRec
#   Repo: Seabattle
#   Repo: sealos
#   Repo: selfreport
#   Repo: simple-java-maven-app
#   Repo: STUDENT
#   Repo: tic-tac-toe
#   Repo: Tic-Tac-Toe-cpp
#   Repo: try-github-repo-pages
#   Repo: usv
#   Repo: WechatBot
#   Repo: workflows-for-hypercrx
#   Repo: WPFCalculator
#   Repo: WPF_LoginUI
#   Repo: wxharry
#   Repo: wxharry.github.io
#   Repo: ybat
#   Repo: yuque-hexo
# Follower: TieWay59
#   Repo: 2022-LFX-Mentorship-Tracker
#   Repo: 22-Spring-OSDD
#   Repo: cargo-xtask
#   Repo: ChatALL
#   Repo: cn.vuejs.org
#   Repo: community
#   Repo: CR_Metrics_Model
#   Repo: dufs
#   Repo: empty
#   Repo: gccrs
#   Repo: gender-classify
#   Repo: GitHub-blocks-example
#   Repo: gping
#   Repo: grimoirelab
#   Repo: grimoirelab-cereslib
#   Repo: grimoirelab-elk
#   Repo: grimoirelab-graal
#   Repo: grimoirelab-kidash
#   Repo: grimoirelab-kingarthur
#   Repo: grimoirelab-manuscripts
#   Repo: grimoirelab-perceval
#   Repo: grimoirelab-perceval-finos
#   Repo: grimoirelab-perceval-gitee
#   Repo: grimoirelab-perceval-mozilla
#   Repo: grimoirelab-perceval-opnfv
#   Repo: grimoirelab-perceval-puppet
#   Repo: grimoirelab-perceval-weblate
#   Repo: grimoirelab-sigils
#   Repo: grimoirelab-sirmordred
#   Repo: grimoirelab-sortinghat
#   Repo: grimoirelab-toolkit
#   Repo: grimoirelab-tutorial
#   Repo: gsoc-2022
#   Repo: HappyACEveryday
#   Repo: hello-world-greeting
#   Repo: helloworld
#   Repo: hypertrons-crx
#   Repo: issue-action-test
#   Repo: ldap-test-tool
#   Repo: multissh
#   Repo: next-play-app-01
#   Repo: nginx-ldap-auth
#   Repo: openai-function-calling
#   Repo: oss101
#   Repo: oss101-awesome-list
#   Repo: OSSDevGov2022
#   Repo: project-guidelines
#   Repo: project-urls-manager-vscode-extension
#   Repo: ratatui
#   Repo: revolt-backend
#   Repo: Rust
#   Repo: rust-tryouts
#   Repo: rustls
#   Repo: rye
#   Repo: ScatterPlotPainter
#   Repo: sherlock
#   Repo: thinking-thoughts
#   Repo: this-week-in-rust
#   Repo: TieWay59
#   Repo: tieway59-beta.github.io
#   Repo: TieWay59.github.io
#   Repo: tmplz
#   Repo: Tree-Style-History
#   Repo: ttrmp_front
#   Repo: ttrmp_server
#   Repo: tw59-ghaction-playground
#   Repo: wasi-crypto
#   Repo: wasm-learning
#   Repo: WasmEdge
#   Repo: wasmedge_hostfunctionexample_interface
#   Repo: web-extensions
#   Repo: youki
# Follower: X-lab2017
#   Repo: .github
#   Repo: 2022-SocialComputing
#   Repo: 22-Spring-OSDD
#   Repo: AccelerateDevOps
#   Repo: AccelerateDevOps-1
#   Repo: CCSADP
#   Repo: chinese_decade_open_source_insight_report
#   Repo: dase-2023-autumn
#   Repo: DaSE101
#   Repo: DaseDevops
#   Repo: DaSE_lab
#   Repo: data-cat
#   Repo: Deep-Learning-with-TensorFlow
#   Repo: DesignThinking-LeanStartup
#   Repo: docker-cli
#   Repo: ds-2023-autumn
#   Repo: G6VP
#   Repo: gi-assets-xlab
#   Repo: git
#   Repo: github-analysis-report-2019
#   Repo: github-graphql-client
#   Repo: github-push-action
#   Repo: go-study-guide
#   Repo: grimoirelab
#   Repo: grimoirelab-elk
#   Repo: grimoirelab-elk-gitee
#   Repo: grimoirelab-sigils
#   Repo: grimoirelab-sirmordred
#   Repo: HOSAS
#   Repo: hypertrons-crx
#   Repo: ICSE-OpenRank-material
#   Repo: minicourse-k8s
#   Repo: MSR-2024-npm-OpenRank-material
#   Repo: od-api
#   Repo: open-certified
#   Repo: open-dashboard
#   Repo: open-digger
#   Repo: open-digger-cli
#   Repo: open-digger-jupyterlab-nodejs
#   Repo: open-digger-website
#   Repo: open-galaxy
#   Repo: open-galaxy-backend
#   Repo: open-leaderboard
#   Repo: open-lecture
#   Repo: open-perf
#   Repo: open-research
#   Repo: open-tag
#   Repo: open-tag-web
#   Repo: open-widgets
#   Repo: open-wonderland
#   Repo: OpenBench
#   Repo: openrank-neo4j-gds
#   Repo: OpenTEA101
#   Repo: oss101
#   Repo: oss101-awesome-list
#   Repo: OSSDevGov2021
#   Repo: OSSDevGov2022
#   Repo: pp_cc
#   Repo: scripts-for-xlab-ospo-dashboard
#   Repo: sirmordred
#   Repo: TensorFlow-Getting-Started
#   Repo: WIP-feedback
#   Repo: x-lab-paper_co-read
#   Repo: X-lab-website
#   Repo: X-lab2017.github.io
#   Repo: xlab-website
# Follower: xiaoya-yaya
#   Repo: alc-site
#   Repo: allAboutTest-Docs
#   Repo: badging-documenation
#   Repo: badging-readthedocs
#   Repo: badging-template
#   Repo: community
#   Repo: community-handbook
#   Repo: documentation
#   Repo: event-diversity-and-inclusion
#   Repo: final-assignment-open-source
#   Repo: frank-zsy
#   Repo: github-analysis-report-2019
#   Repo: hypertrons-crx
#   Repo: open-digger
#   Repo: open-research
#   Repo: ospolandscape
#   Repo: ospology
#   Repo: OSSDevGov2021
#   Repo: project-diversity-and-inclusion
#   Repo: research-4whs
#   Repo: season-of-docs
#   Repo: servicecomb-pack
#   Repo: translations
#   Repo: website
#   Repo: wg-common
#   Repo: wg-metrics-models
#   Repo: xiaoya-yaya
#   Repo: Yaya-s-blog
# Follower: wj23027
#   Repo: AccelerateDevOps
#   Repo: ant-design
#   Repo: DaSE
#   Repo: dase-2023-autumn
#   Repo: dase-practice-course
#   Repo: FedTree
#   Repo: G6VP
#   Repo: gi-assets-xlab
#   Repo: hypertrons-crx
#   Repo: iSelenium_Python
#   Repo: open-digger
#   Repo: open-leaderboard
#   Repo: open-research
#   Repo: OpenTEA101
#   Repo: oss101
#   Repo: wj23027.github.io
# Follower: ArDoCo
#   Repo: .github
#   Repo: actions
#   Repo: ADDClass
#   Repo: ArDoCo-eclipse
#   Repo: ArDoCo-parent
#   Repo: ardoco.github.io
#   Repo: Benchmark
#   Repo: bigbluebutton
#   Repo: CaseStudies
#   Repo: CLI
#   Repo: CodeModelExtractors
#   Repo: Core
#   Repo: Core-Docs
#   Repo: DetectingInconsistenciesInSoftwareArchitectureDocumentationUsingTraceabilityLinkRecovery
#   Repo: DockerManager4J
#   Repo: Evaluator
#   Repo: GUI
#   Repo: jabref
#   Repo: java-python-bridge-example
#   Repo: JavaModelExtractor
#   Repo: MediaStore3
#   Repo: NLWrapper
#   Repo: PARSEGraphImprove
#   Repo: Replication-Package-ICSE24_Recovering-Trace-Links-Between-Software-Documentation-And-Code
#   Repo: SimpleTracelinkDiscovery
#   Repo: StanfordCoreNLP-Provider-Service
#   Repo: SWATTR
#   Repo: TaxonomyForDesignDecisionsInSAD
#   Repo: teammates
#   Repo: TeaStore
#   Repo: textAnalysis4Eclipse
#   Repo: textannotation
#   Repo: textprovider-json
#   Repo: wmd4j
# Follower: Tenth-crew
#   Repo: git_test
#   Repo: laughtale
#   Repo: open-research
#   Repo: system-design-101
# Follower: HalloMelon
#   Repo: OpenSODA
# Follower: ECNU
#   Repo: contact_tracing
#   Repo: Data-Thinking-and-Practice
#   Repo: digital-literacy-framework
#   Repo: ecnu-datasync-cli
#   Repo: ecnu-openapi-sdk-csharp
#   Repo: ecnu-openapi-sdk-go
#   Repo: ecnu-openapi-sdk-java
#   Repo: ecnu-openapi-sdk-nodejs
#   Repo: ecnu-openapi-sdk-python
#   Repo: ldap-test-tool
#   Repo: multissh
#   Repo: nginx-ldap-auth
#   Repo: open-geoip
#   Repo: Open-OAuth2Playground
#   Repo: OpenDL
#   Repo: OpenQuest
#   Repo: OpenSODA
# Follower: longyanz
#   Repo: open-digger
#   Repo: OSSDevGov2022
# Follower: lhbvvvvv
#   Repo: AccelerateDevOps
#   Repo: ECNU-FedTree-Challenge
#   Repo: FedTree
#   Repo: hypertrons-crx
#   Repo: lhbvvvvv.github.io
#   Repo: open-digger
#   Repo: OpenTEA101
#   Repo: oss101
# Follower: OpenEduTech
#   Repo: .github
#   Repo: AccelerateDevOps
#   Repo: BCLT-Tutorial
#   Repo: CCSADP
#   Repo: DaSE-Grad-101
#   Repo: DaseDevOps
#   Repo: EduPerf
#   Repo: EduTechResearch
#   Repo: go-geoip
#   Repo: MPSD
#   Repo: OpenCCST
#   Repo: OpenDaSE
#   Repo: OpenEduGnn
#   Repo: OpenEduKG
#   Repo: OpenShuishan
#   Repo: ppcloud2
# Follower: Zzzzzhuzhiwei
#   Repo: AccelerateDevOps
#   Repo: community
#   Repo: ds-2023-autumn
#   Repo: ECNU-FedTree-Challenge
#   Repo: explore
#   Repo: FedTree
#   Repo: hypertrons-crx
#   Repo: open-digger
#   Repo: open-research
#   Repo: OpenTEA101
#   Repo: oss101
#   Repo: signature
#   Repo: SoftwareTagRecommender
#   Repo: StellarTop
#   Repo: Zzzzzhuzhiwei
#   Repo: Zzzzzhuzhiwei.github.io
# Follower: wangyantong2000
#   Repo: 502-Bad-Gateway
#   Repo: EfficientTools
#   Repo: go-by-example
#   Repo: minzhengKGQA
